# %% [markdown]
# # 태그 컬럼과 간략한 설명 컬럼 추가하는 코드

# %% [markdown]
# ### 태그 컬럼과 short info 컬럼 생성

# %%
import pandas as pd

# %%
tour_df= pd.read_csv('찐찐막 전국 데이터.csv')
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_17804\3215735881.py:1: DtypeWarning: Columns (3,56,58,59,60,61,64,65,68,69,70,71,83,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   tour_df= pd.read_csv('찐찐막 전국 데이터.csv')

# %%
tour_df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
add_df = pd.read_csv('C:\\Users\\Playdata\\OneDrive\\바탕 화면\\GIT\\crawling-data\\합친 데이터셋\\additional_crawling_csv\\태그데이터(전체_오류제거버전).csv')
add_df
# Out:
#               place                       info  \
# 0            부평역북광장               사람들이 오가는 중심지
# 1        경주 구정동 방형분           신라 무덤 중 유일한 네모무덤
# 2             달맞이광장           정월대보름 행사가 열리는 광장
# 3           경주 진평왕릉     선덕여왕의 아버지인 제26대 진평왕의 능
# 4               법성포   조상들의 얼과 전통을 고스란히 간직한 법성포
# ...             ...                        ...
# 21020          구니CC  여러 코스 디자인으로 재미를 느낄 수 있는 곳
# 21021        군위오펠GC      팔공산 자락의 아름다움과 함께하는 골프
# 21022          문경GC             청정 지역에서 즐기는 골프
# 21023  씨사이드파크하늘구름광장       가족과 함께 나들이 하기에 좋은 광장
# 21024     켄싱턴리조트 가평       가족과 즐거운 시간 보내기 좋은 호텔
#
#                                               태그
# 0         관광지 대아지하상가 부평역 부평역광장 부평지하상가 부평축제 인천1호선
# 1       관광지 역사 역사공부 역사관광지 역사를품은곳 역사문화재 역사속
# 2       관광지 여주 여주가볼만한곳 여주차박 여주축제 정월대보름 정월대보름축제
# 3      경주나들이 경주여행 관광지 아름다운왕릉 진평왕릉 진평왕릉숲 피크닉하기좋은곳
# 4           경치좋은곳 관광지 바다경치 영광가볼만한곳 자연 자연풍경 전라권
# ...                                          ...
# 21020                   골프관광 골프여행 구니CC 국내골프장 레포츠
# ...

# %%
add_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21025 entries, 0 to 21024
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   place   21025 non-null  object
#  1   info    20979 non-null  object
#  2   태그      21025 non-null  object
# dtypes: object(3)
# memory usage: 492.9+ KB
# (None,
#  Empty DataFrame
#  Columns: [place, info, 태그]
#  Index: [])

# %% [markdown]
# ### 태그와 짧은 내용 같이 담기

# %%
def add_tag_and_short_info_with(add_df):
    # add_df 정보 먼저 담기
    add_df_data = {}
    for idx in range(len(add_df)):
        if type(add_df.iloc[idx]['info']) ==float:
            add_df_data[add_df.iloc[idx]['place']] = add_df.iloc[idx]['태그'].strip()
        elif type(add_df.iloc[idx]['태그'])==float:
            add_df_data[add_df.iloc[idx]['place']] = add_df.iloc[idx]['info'].strip()
        else:
            add_df_data[add_df.iloc[idx]['place']] = add_df.iloc[idx]['info'].strip() + " " + add_df.iloc[idx]['태그'].strip()
    
    # {장소이름 : "인포 태그"} 로 저장
    return add_df_data

# %%
add_df_data = add_tag_and_short_info_with(add_df)
add_df_data
# Out:
# {'부평역북광장': '사람들이 오가는 중심지 관광지 대아지하상가 부평역 부평역광장 부평지하상가 부평축제 인천1호선',
#  '경주 구정동 방형분': '신라 무덤 중 유일한 네모무덤 관광지 역사 역사공부 역사관광지 역사를품은곳 역사문화재 역사속',
#  '달맞이광장': '정월대보름 행사가 열리는 광장 관광지 여주 여주가볼만한곳 여주차박 여주축제 정월대보름 정월대보름축제',
#  '경주 진평왕릉': '선덕여왕의 아버지인 제26대 진평왕의 능 경주나들이 경주여행 관광지 아름다운왕릉 진평왕릉 진평왕릉숲 피크닉하기좋은곳',
#  '법성포': '조상들의 얼과 전통을 고스란히 간직한 법성포 경치좋은곳 관광지 바다경치 영광가볼만한곳 자연 자연풍경 전라권',
#  '경주 황룡사지': '신라 호국불교의 상징 황룡사의 터 경주여행 관광지 신라유적지 신라호국불교 신라황룡사 역사 역사공부',
#  '고창 청농원': '드넓은 핑크뮬리정원과 가을꽃을 만나보세요! SNS감성사진 감성사진 관광지 사진찍기 사진찍기좋은곳 사진촬영',
#  '이포보': '아름다운 경치를 자랑하는 여주 시민들의 힐링공간 가볼래터 관광지 라이딩 라이딩명소 산책로 산책로캠핑장 야경 야경이예쁜',
#  '수원시립미술관': '화성[華城]의 숨결과 현대미술이 어우러지는 공존의 예술공간 문화시설 문화예술공간 미술관 복합문화공간 수도권 수원시립미술관',
#  '득량역 추억의 거리': '그때 그 시절의 추억을 그대로 재현한 거리 감성사진 관광지 데이트장소추천 보성가볼만한곳 부모님과함께 사진찍기좋은곳',
#  '여주도자세상': '국내 최대 규모의 도자기 전문 쇼핑몰과 공예체험 가족여행 가족체험여행 공예체험 공예품 관광지 교과서속여행 당일치기여행',
#  '경주 문무대왕릉': '삼국통일을 이룩한 문무대왕의 수중릉 2024_여행가는달과함께하는_발도장여행지 감은사 경북권반려동물여행지',
#  '톱머리 해수욕장': '넓은 백사장과 해송 숲이 아름다운 해수욕장 가족여행 경치좋은곳 관광지 낙조 바다낚시 바다풍경 아이와함께',
# ...

# %%
def add_to_csv_with(add_df_data,tour_df):
    additional_list = []

    for place in list(tour_df['place']):
        if place in add_df_data:
            additional_list.append(add_df_data[place])
        else:
            additional_list.append(None)    # None으로 넣어주기
    tour_df['태그'] = additional_list       # 태그라는 컬럼에 같이 넣어주기
    return tour_df

# %%
tour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19881 entries, 0 to 19880
# Data columns (total 84 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   place       19881 non-null  object
#  1   info        19881 non-null  object
#  2   문의 및 안내     70 non-null     object
#  3   홈페이지        15503 non-null  object
#  4   주소          19881 non-null  object
#  5   이용시간        18206 non-null  object
#  6   휴일          17098 non-null  object
#  7   주차          17037 non-null  object
#  8   화장실         10228 non-null  object
#  9   입장료         7398 non-null   object
#  10  접근로         4397 non-null   object
#  11  review      8769 non-null   object
#  12  주차 요금       918 non-null    object
#  13  이용요금        5788 non-null   object
#  14  체험          2442 non-null   object
#  15  출입통로        3928 non-null   object
#  16  장애인 주차 안내   3702 non-null   object
#  17  엘리베이터       1686 non-null   object
#  18  수유실         755 non-null    object
# ...

# %%
tour_df.drop(['사우나실 여부','캠프파이어 여부','스포츠 시설 여부','자전거 대여 여부','공용 PC실 여부','휘트니스 센터 여부','노래방 여부','청각장애용 객실','뷰티시설여부','공용 샤워실 여부','청각장애 기타상세'],axis=1,inplace=True)

# %%
tour_df.to_csv('찐찐찐막 전국 데이터.csv',index=False)

# %%
tour_df = pd.read_csv("찐찐찐막 전국 데이터.csv")
tour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19881 entries, 0 to 19880
# Data columns (total 73 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   place       19881 non-null  object
#  1   info        19881 non-null  object
#  2   문의 및 안내     70 non-null     object
#  3   홈페이지        15503 non-null  object
#  4   주소          19881 non-null  object
#  5   이용시간        18206 non-null  object
#  6   휴일          17098 non-null  object
#  7   주차          17037 non-null  object
#  8   화장실         10228 non-null  object
#  9   입장료         7398 non-null   object
#  10  접근로         4397 non-null   object
#  11  review      8769 non-null   object
#  12  주차 요금       918 non-null    object
#  13  이용요금        5788 non-null   object
#  14  체험          2442 non-null   object
#  15  출입통로        3928 non-null   object
#  16  장애인 주차 안내   3702 non-null   object
#  17  엘리베이터       1686 non-null   object
#  18  수유실         755 non-null    object
# ...

# %%
tour_add_df = add_to_csv_with(add_df_data,tour_df)
tour_add_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19881 entries, 0 to 19880
# Data columns (total 74 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   place       19881 non-null  object
#  1   info        19881 non-null  object
#  2   문의 및 안내     70 non-null     object
#  3   홈페이지        15503 non-null  object
#  4   주소          19881 non-null  object
#  5   이용시간        18206 non-null  object
#  6   휴일          17098 non-null  object
#  7   주차          17037 non-null  object
#  8   화장실         10228 non-null  object
#  9   입장료         7398 non-null   object
#  10  접근로         4397 non-null   object
#  11  review      8769 non-null   object
#  12  주차 요금       918 non-null    object
#  13  이용요금        5788 non-null   object
#  14  체험          2442 non-null   object
#  15  출입통로        3928 non-null   object
#  16  장애인 주차 안내   3702 non-null   object
#  17  엘리베이터       1686 non-null   object
#  18  수유실         755 non-null    object
# ...

# %%
tour_df[['place','태그']].to_csv('태그빈것들채워주세요',index=False)

# %%
## 태그 빈 csv 파일 5개로 나누기
df = pd.read_csv('태그빈것들채워주세요.csv')
df[:4001].to_csv('태그빈것들1.csv',index=False)
df[4001:8001].to_csv('태그빈것들2.csv',index=False)
df[8001:12001].to_csv('태그빈것들3.csv',index=False)
df[12001:16001].to_csv('태그빈것들4.csv',index=False)
df[16001:].to_csv('태그빈것들5.csv',index=False)

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
tour_df = pd.read_csv('./찐찐찐막 전국 데이터.csv')
tag_df = pd.read_csv('./비어있는 태그/태그채우고합친파일.csv')

len(tour_df), len(tag_df)
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_23108\369305407.py:1: DtypeWarning: Columns (2,55,57,58,59,60,63,64,67,68,69,70,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   tour_df = pd.read_csv('./찐찐찐막 전국 데이터.csv')
# (19854, 19854)

# %%
tags = []
for i in range(len(tag_df)):
    tags.append(tag_df.iloc[i]['태그'])
tags
# Out:
# ['조선의 근본을 상징하는 국왕의 제사터 관광지 문화유적 문화유적돌아보기 서울 서울관광지 서울역사관광 역사관광',
#  '그날의 역사와 의의를 자세히 알 수 있는 곳 5.18 518민주화운동기록관 5·18민주화운동기록관 광주 광주여행 기록관',
#  '봄을 먼저 맞이하는 곳 광주가볼만한곳 광주꽃구입 광주꽃단지 광주꽃시장 광주나무구입 광주여행',
#  '생산자와 소비자를 보호하는 호남 최대의 도매시장 농수산물 농수산물검사소 농수산물경매 도매시장 서부농수산물도매시장',
#  '코스모스와 억새 물결이 일렁이는 공원 관광지 광주가볼만한곳 광주코스모스 산동교 산동교친수공원 유채꽃명소',
#  '우리나라 최초의 폐선부지 공원 2022친환경추천여행지 관광지 광주 광주_여행지_추천 광주가볼만한곳',
#  '일본통신사 행차를 기록한 조형선생을 기리기 위한 비 관광지 광주취병조형유허비 교과서속여행 문화재 역사 역사공부 역사를품은곳',
#  '우리나라 무덤의 발달사와 한일관계의 역사를 보여주는 삼국시대 고분 관광지 광주고분 광주월계동장고분 신라고분 역사 역사공부 역사관광지',
#  '석불입상과 함께 무심히 서있는 신라계 고려 석탑 고려5층탑 고려오층탑 관광지 광주신룡동오층석탑 역사 역사공부 역사관광지',
#  '초야에 묻힌 선비의 효를 말해주는 조선시대 기효증의 정자 관광지 광산칠송정 광주칠송정 기대승 역사 역사공부 역사관광지',
#  '가족 나들이하기 좋은 도심 공원 경암근린공원 관광지 도심속숲 도심속휴식 무장애나눔길 어린이와가볼만한곳',
#  '규모는 작지만 없는 게 없는 알찬 시장 공설시장 광주오일장 비아5일시장 쇼핑 시장 오일장 정이넘치는시장',
#  '남도의례음식 이수자의 향토음식 기반 체험프로그램 관광두레 관광두레_주민사업체 관광지 광주 광주_관광두레 남도의례음식',
#  '성리학자 고봉(高峰) 기대승(奇大升)을 배향하는 곳 관광지 역사 역사공부 역사관광 역사관광지 역사를품은곳 역사문화재',
# ...

# %%
tour_df['태그'] = tags
tour_df
# Out:
#                  place                                               info  \
# 0                  사직단  광주의 사직단은 광주 양림동 광주광역시립사직도서관 위쪽 사직공원에 있는 조선시대의 ...
# 1        5·18민주화운동 기록관  5·18 민주화운동은 1980년 5월 18일부터 열흘간 전라남도 광주에서 촉발된 항...
# 2               상무화훼단지  상무화훼단지는 365일 활짝 피어있는 꽃들을 만날 수 있는 곳이다. 김대중컨벤션센터...
# 3           서부농수산물도매시장  광주 서부농수산물도매시장은 2004년 4월 개장하여 일일 1,500t 규모의 농수산...
# 4              산동교친수공원  광주광역시 북구 동림동 푸른 마을 옆에 있는 산동교 친수공원은 광주의 관문에 해당하...
# ...                ...                                                ...
# 19849        문경새재 도립공원  문경읍에서 서북쪽으로 깊은 협곡을 따라 3.5km 가면 조선 숙종 34년 (1708...
# 19850      소백산국립공원(영주)  1987년 18번째 국립공원으로 지정되었으며 면적은 322.011㎢로 지리산, 설악...
# 19851       울진 금강소나무숲길  경북 울진군 서면 소광리 금강소나무 집단분포지는 숙종 때 황장봉산으로 지정 관리 하...
# 19852  낙동 승곡마을(농촌체험마을)  낙동승곡마을의 구상화강암은 세계 어느 지역에서도 볼 수 있는 것으로 국가지정 문화재...
# 19853              영지사  영천 구룡산에 있는 사찰 영지사는 대한불교 조계종 제10교구 본사 은해사의 말사이다...
#
#       문의 및 안내                                               홈페이지  \
# ...

# %%
tour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19854 entries, 0 to 19853
# Data columns (total 74 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   place       19854 non-null  object
#  1   info        19854 non-null  object
#  2   문의 및 안내     70 non-null     object
#  3   홈페이지        15484 non-null  object
#  4   주소          19854 non-null  object
#  5   이용시간        18187 non-null  object
#  6   휴일          17078 non-null  object
#  7   주차          17018 non-null  object
#  8   화장실         10219 non-null  object
#  9   입장료         7395 non-null   object
#  10  접근로         4393 non-null   object
#  11  review      8759 non-null   object
#  12  주차 요금       918 non-null    object
#  13  이용요금        5779 non-null   object
#  14  체험          2442 non-null   object
#  15  출입통로        3926 non-null   object
#  16  장애인 주차 안내   3699 non-null   object
#  17  엘리베이터       1685 non-null   object
#  18  수유실         755 non-null    object
# ...

# %%
tour_df.to_csv('찐찐찐찐막 전국 데이터.csv',index=False)

# %% [markdown]
# ### 태그와 짧은 내용 따로 담기

# %%
def add_tag_and_short_info_sep(add_df):
    # add_df 정보 먼저 담기
    add_df_data = {}
    for idx in range(len(add_df)):
        if type(add_df.iloc[idx]['info']) ==float:
            add_df_data[add_df.iloc[idx]['place']] = {'태그': add_df.iloc[idx]['태그'].strip(), 'short_info':''}
        elif type(add_df.iloc[idx]['태그']) ==float:
            add_df_data[add_df.iloc[idx]['place']] = {'태그': '', 'short_info': add_df.iloc[idx]['info']}
        else:
            add_df_data[add_df.iloc[idx]['place']] = {'태그': add_df.iloc[idx]['태그'].strip(), 'short_info': add_df.iloc[idx]['info'].strip()}
    return add_df_data
    # {장소이름 : { 태그 : 태그들, 'short_info' : 짧은 설명}} 로 저장

# %%
add_df_data = add_tag_and_short_info_sep(add_df)
add_df_data
# Out:
# {'부평역북광장': {'태그': '관광지 대아지하상가 부평역 부평역광장 부평지하상가 부평축제 인천1호선',
#   'short_info': '사람들이 오가는 중심지'},
#  '경주 구정동 방형분': {'태그': '관광지 역사 역사공부 역사관광지 역사를품은곳 역사문화재 역사속',
#   'short_info': '신라 무덤 중 유일한 네모무덤'},
#  '달맞이광장': {'태그': '관광지 여주 여주가볼만한곳 여주차박 여주축제 정월대보름 정월대보름축제',
#   'short_info': '정월대보름 행사가 열리는 광장'},
#  '경주 진평왕릉': {'태그': '경주나들이 경주여행 관광지 아름다운왕릉 진평왕릉 진평왕릉숲 피크닉하기좋은곳',
#   'short_info': '선덕여왕의 아버지인 제26대 진평왕의 능'},
#  '법성포': {'태그': '경치좋은곳 관광지 바다경치 영광가볼만한곳 자연 자연풍경 전라권',
#   'short_info': '조상들의 얼과 전통을 고스란히 간직한 법성포'},
#  '경주 황룡사지': {'태그': '경주여행 관광지 신라유적지 신라호국불교 신라황룡사 역사 역사공부',
#   'short_info': '신라 호국불교의 상징 황룡사의 터'},
#  '고창 청농원': {'태그': 'SNS감성사진 감성사진 관광지 사진찍기 사진찍기좋은곳 사진촬영',
#   'short_info': '드넓은 핑크뮬리정원과 가을꽃을 만나보세요!'},
#  '이포보': {'태그': '가볼래터 관광지 라이딩 라이딩명소 산책로 산책로캠핑장 야경 야경이예쁜',
#   'short_info': '아름다운 경치를 자랑하는 여주 시민들의 힐링공간'},
#  '수원시립미술관': {'태그': '문화시설 문화예술공간 미술관 복합문화공간 수도권 수원시립미술관',
#   'short_info': '화성[華城]의 숨결과 현대미술이 어우러지는 공존의 예술공간'},
# ...

# %%
def add_to_csv(add_df_data,tour_df):
    tag_list = []
    short_info_list = []

    for place in list(tour_df['place']):
        if place in add_df_data:
            tag_list.append(add_df_data[place]['태그'])
            short_info_list.append(add_df_data[place]['short_info'])
        else:
            tag_list.append(None)       # None으로 넣어주기
            short_info_list.append(None)    # None으로 넣어주기
    tour_df['태그'] = tag_list
    tour_df['short_info'] = short_info_list
    return tour_df

# %%
tour_df = add_to_csv(add_df_data,tour_df)
tour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20074 entries, 0 to 20073
# Data columns (total 86 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   place       20074 non-null  object
#  1   info        20074 non-null  object
#  2   문의 및 안내     70 non-null     object
#  3   홈페이지        15676 non-null  object
#  4   주소          20074 non-null  object
#  5   이용시간        18238 non-null  object
#  6   휴일          17130 non-null  object
#  7   주차          17202 non-null  object
#  8   화장실         10300 non-null  object
#  9   입장료         7400 non-null   object
#  10  접근로         4484 non-null   object
#  11  review      8830 non-null   object
#  12  주차 요금       918 non-null    object
#  13  이용요금        5813 non-null   object
#  14  체험          2446 non-null   object
#  15  출입통로        4012 non-null   object
#  16  장애인 주차 안내   3796 non-null   object
#  17  엘리베이터       1764 non-null   object
#  18  수유실         762 non-null    object
# ...

# %% [markdown]
# ---
# ### Document로 만들기

# %%
import pandas as pd

# %%
df = pd.read_csv("전국 데이터.csv")
add_df = pd.read_csv('추가 데이터1.csv')
# Out:
# C:\Users\brain\AppData\Local\Temp\ipykernel_6472\479588644.py:1: DtypeWarning: Columns (2,55,63,64,69,70,72,73,74,75,77,79,80,81,82,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("전국 데이터.csv")

# %%
add_df_data = add_tag_and_short_info_sep(add_df)
tour_df = add_to_csv(add_df_data,tour_df)

# %%
tour_df.to_csv('예시용.csv',index=False)

# %%
import preprocess_functions as pf

data = pf.make_tag_page_content('예시용.csv')
# Out:
# c:\Users\brain\Desktop\3차 프로젝트\GIT\crawling-data\합친 데이터셋\preprocess_functions.py:120: DtypeWarning: Columns (2,55,63,64,69,70,72,73,74,75,77,79,80,81,82,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_df = pd.read_csv(file_path)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\brain\anaconda3\envs\llm_env\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
from langchain_core.documents import Document
data = []
new_df = pd.read_csv('예시용.csv')

new_df.info()
new_df = new_df[['좌석수','공용 PC실 여부']].astype(dtype='object')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20074 entries, 0 to 20073
# Data columns (total 86 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   place       20074 non-null  object
#  1   info        20074 non-null  object
#  2   문의 및 안내     70 non-null     object
#  3   홈페이지        15676 non-null  object
#  4   주소          20074 non-null  object
#  5   이용시간        18238 non-null  object
#  6   휴일          17130 non-null  object
#  7   주차          17202 non-null  object
#  8   화장실         10300 non-null  object
#  9   입장료         7400 non-null   object
#  10  접근로         4484 non-null   object
#  11  review      8830 non-null   object
#  12  주차 요금       918 non-null    object
#  13  이용요금        5813 non-null   object
#  14  체험          2446 non-null   object
#  15  출입통로        4012 non-null   object
#  16  장애인 주차 안내   3796 non-null   object
#  17  엘리베이터       1764 non-null   object
#  18  수유실         762 non-null    object
# ...

# %%
for idx in range(len(new_df)):
    tag_data = ''
    meta_data = {}
    row = new_df.iloc[idx][new_df.iloc[idx].notna()]
    print(row)

    for col in list(row.index):     # None이 아닌 컬럼들 == row.index 
        if col == '태그':
            if row[col] is not None:
                tag_data = row[col]
                print(tag_data)
        else:
            modified_data = row[col].replace('\r\n',' ')
            modified_data = modified_data.replace('\n', ' ')
            modified_data = modified_data.replace('\r',' ')
            meta_data[col] = modified_data
    data.append(Document(
            page_content=tag_data,
            metadata=meta_data
        ))
    break
# Out:
# place                                                  사직단
# info     광주의 사직단은 광주 양림동 광주광역시립사직도서관 위쪽 사직공원에 있는 조선시대의 ...
# 홈페이지                           https://tour.gwangju.go.kr/
# 주소                                    광주광역시 남구 사직길 49 (사동)
# 이용시간                                                 상시 개방
# 휴일                                                    연중무휴
# 주차                                                     불가능
# 화장실                                 장애인 화장실 있음(사직공원 공중화장실)
# 입장료                                                     무료
# 접근로                            사직단까지 경사로가 설치되어 있음_무장애 편의시설
# Name: 0, dtype: object

# %%
data
# Out:
# [Document(metadata={'place': '사직단', 'info': '광주의 사직단은 광주 양림동 광주광역시립사직도서관 위쪽 사직공원에 있는 조선시대의 제단이다. 사직단은 신성한 장소로, 사()는 땅의 신, 직()은 곡식의 신을 가리킨다. 사직단은 땅의 신과 곡식의 신에게 제사를 올리며 나라의 안녕과 풍요를 기원하는 사직제를 지내는 공간이다. 사직단은 종묘와 함께 신성시되어 종사()라고도 했다. 사직단은 서울뿐 아니라 각 군현에도 있었으며, 기곡제, 기우제, 기청제, 기설제 등을 지냈다. 광주 사직단 크기는 서울 사직단 규모(2장 5척의 정사각형, 높이 3척)의 반 정도이다. 갑오년 이후 폐지되었으며, 한말에는 사직단을 군사 훈련장으로 사용하기도 했었다. 1971년 동물원이 들어서면서 그 자취가 없어졌는데, 1993년 광주시가 사직단을 복원, 1994년 광주 향우회 회장(최기영)에 의해 100년 만에 사직제가 부활되었다. 국토와 오곡은 민생의 근본이므로 삼국 시대부터 국태민안을 기원하는 사직단을 설치하여 친히 왕이 나가서 제사를 올렸다. 지방에서는 성주가 제주가 되었으므로 광주 목사가 매년 제사를 주관하였다.', '홈페이지': 'https://tour.gwangju.go.kr/', '주소': '광주광역시 남구 사직길 49 (사동)', '이용시간': '상시 개방', '휴일': '연중무휴', '주차': '불가능', '화장실': '장애인 화장실 있음(사직공원 공중화장실)', '입장료': '무료', '접근로': '사직단까지 경사로가 설치되어 있음_무장애 편의시설'}, page_content='')]
