# %% [markdown]
# ## 태그 컬럼을 csv 파일에 추가하기

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\Playdata\OneDrive\\바탕 화면\\git folder\\3rd_project\\crawling-data\\합친 데이터셋\\찐막 전국 데이터.csv')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_17196\3146450609.py:1: SyntaxWarning: invalid escape sequence '\O'
#   df = pd.read_csv('C:\\Users\\Playdata\OneDrive\\바탕 화면\\git folder\\3rd_project\\crawling-data\\합친 데이터셋\\찐막 전국 데이터.csv')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_17196\3146450609.py:1: DtypeWarning: Columns (2,55,57,58,59,60,63,64,67,68,69,70,82,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\\Users\\Playdata\OneDrive\\바탕 화면\\git folder\\3rd_project\\crawling-data\\합친 데이터셋\\찐막 전국 데이터.csv')
#                  place                                               info  \
# 0                  사직단  광주의 사직단은 광주 양림동 광주광역시립사직도서관 위쪽 사직공원에 있는 조선시대의 ...
# 1        5·18민주화운동 기록관  5·18 민주화운동은 1980년 5월 18일부터 열흘간 전라남도 광주에서 촉발된 항...
# 2               상무화훼단지  상무화훼단지는 365일 활짝 피어있는 꽃들을 만날 수 있는 곳이다. 김대중컨벤션센터...
# ...

# %%
df.columns
# Out:
# Index(['place', 'info', '문의 및 안내', '홈페이지', '주소', '이용시간', '휴일', '주차', '화장실',
#        '입장료', '접근로', 'review', '주차 요금', '이용요금', '체험', '출입통로', '장애인 주차 안내',
#        '엘리베이터', '수유실', '판매 품목', '이용가능시설', '주차요금', '지정현황', '체험가능 연령', '유모차',
#        '휠체어', '지체장애 기타 상세', '입점브랜드', '규모', '대중 교통', '주요시설', '할인 정보', '수용인원',
#        '오디오 가이드', '시각장애 기타상세', '관람석', '점자 홍보물', '보조견 동반', '보유장비', '안내 요원',
#        '시설이용료', '부대시설', '점자 블록', '이용 시기', '강습안내', '청각 장애 기타상세', '코스안내',
#        '영유아가족 기타상세', '유아용보조의자', '개장기간', '대여안내', '유도안내 설비', '예약안내 홈페이지', '객실',
#        '자막 비디오 가이드', '수화 안내', '매표소', '입실시간', '퇴실시간', '객실내 취사 여부', '식음료장',
#        '객실수', '영업시간', '대표메뉴', '취급메뉴', '큰활자 홍보물', '홍보물', '예약안내', '객실유형',
#        '바비큐장여부', '세미나실 여부', '좌석수', '사우나실 여부', '캠프파이어 여부', '스포츠 시설 여부',
#        '자전거 대여 여부', '공용 PC실 여부', '휘트니스 센터 여부', '노래방 여부', '청각장애용 객실', '뷰티시설여부',
#        '공용 샤워실 여부', '청각장애 기타상세', '보조견동반'],
#       dtype='object')

# %%
df[df['객실'].notna()]
# Out:
#                place                                               info  \
# 822          국립대전숲체원  중부권 대표 산림복지시설 국립대전숲체원은 생태 1 급지 빈계산 자락에 위치해 있다....
# 3530         강동오토캠핑장  울산 강동 오토캠핑장은 일반 데크 13면, 필로티 데크 6면으로 구성되어 있으며, ...
# 3641   국립 신불산폭포자연휴양림  신불산폭포자연휴양림은 해발 1천 미터 이상의 수려한 산세와 풍광을 자랑하는 영남알프...
# 5080    정남진 편백숲 우드랜드  정남진 장흥은 산과 바다와 강이 있는 아름다운 생태고을이다. 그중에서도 초록의 상쾌...
# 5086       순천 드라마촬영장  순천 드라마촬영장은 특히 관광지가 많은 전라남도 순천시에 위치한 곳이다. 2006년...
# 5813     국립 회문산자연휴양림  회문산은 북서쪽의 장군봉(투구봉, 해발 780m)과 북쪽 중앙의 회문봉 (큰지붕, ...
# 6494     국립 운장산자연휴양림  진안군 정천면, 주천면, 부귀면과 완주군 동상면에 걸쳐 있는 해발 1,126m의 운...
# 8024    봉수산자연휴양림&수목원  봉수산자연휴양림은 예산 예당저수지(예당관광지) 남서쪽 인근에 솟은 봉수산(483m)...
# 8062      국립 용현자연휴양림  서산 최고봉인 가야산(678.2m)의 북쪽 줄기는 석문봉(656.8m)을 거쳐 일락...
# 8850   소노벨 천안 오션어드벤처  소노벨 천안 오션어드벤처는 중부지역권 최대의 테마워터파크로 로마, 스페인, 베니스 ...
# 8992   국립 희리산해송자연휴양림  1998년 개장한 해송 천연림으로 산 전체가 해송 천연림으로 경관이 수려하다. 또한...
# 9234         청주 상당산성  * 삼국시대 포곡식 석축산성, 상당산성 * 상당산성이란 명칭은 삼국시대 백제의 상당...
# ...
